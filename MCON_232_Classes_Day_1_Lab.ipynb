# %% [markdown]
# <a href="https://colab.research.google.com/github/rwiederblank/MCON232_module6_Ruchama_Wiederblank/blob/main/MCON_232_Classes_Day_1_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MCON 232 Classes Day 1 Lab
# ### your name :

# %%
# sliding window
def longest(s):
  s = s.lower()

  seen = set()
  left = 0
  longest = 0
  best_start = 0

  for right in range(len(s)):
    while s[right] in seen:
      seen.remove(s[left])
      left += 1
    seen.add(s[right])
    current_length = right - left + 1

    if current_length > longest:
      longest = current_length
      best_start = left
  return s[best_start: best_start+longest]

print(longest("abcawuiftasblfqjwahxgygdsjaslhdfawq"))
# Out:
# sblfqjwahxgy

# %%
class Watch:
  def __init__(self, time, date, color):
    self._time = time
    self._date = date
    self._alarm_on = False
    self._alarm_time = None
    self._color = color

  def wind_watch(self):
    print("The watch is wound")

  def set_alarm(self, alarm_time):
    self._alarm_time = alarm_time
    self._alarm_on = True

  def stop_alarm(self):
    self._alarm_on = False
    self._alarm_time = None

  def get_time(self):
    return self._time

  def get_date(self):
    return self._date

  def _fix_watch(self):
    return "watch is fixed"

# %%
my_watch = Watch("10:30 AM", "March 29", "red")
print(my_watch.get_date())
print(my_watch.get_time())
print(my_watch._fix_watch())
# Out:
# March 29
# 10:30 AM
# watch is fixed

# %%
import random
from turtle import *
import math

screen = Screen()
screen.bgcolor("white")

hot_palette = [
"hotpink","deeppink","pink",
"#ff69b4","#ff1493","#ff5c8a","#ff4d6d",
"#ff006e","#ff0a54","#ff477e","#ff7096",
"coral","tomato","orangered",
"#ff7b00","#ff8500","#ff9100","#ff9e00",
"#ff5400","#ff6d00","#ff3c38",
"red","crimson",
"#ff1744","#ff1744","#ff355e",
"magenta","fuchsia",
"#ff00ff","#ff00cc","#ff00aa","#ff0099",
"orchid","mediumorchid","darkorchid",
"#d000ff","#c77dff","#9d4edd","#8338ec",
"violet","blueviolet",
"gold","yellow",
"#ffbe0b","#ffd60a","#ffea00",
"#fb5607","#ff006e","#8338ec","#3a86ff"
]

green_palette = ["springgreen","mediumspringgreen","lime","limegreen",
                 "lawngreen","chartreuse","greenyellow","palegreen",
                 "lightgreen","mediumseagreen","seagreen","yellowgreen",
                 "darkseagreen","lightseagreen","#00ff7f","#39ff14",
                 "#7fff00","#66ff66","#99ff66","#66ff99","#33ff99","#00ff99"]


class Flower(Turtle):
    # constructor
    def __init__(self,
                 x : int,
                 y : int,
                 petals :int,
                 size : int,
                 petal_color : str,
                 stamen_color : str,
                 stem_color : str
                 ):
        super().__init__()
        self.x = x
        self.y = y
        self.petals = petals
        self.size = size
        self.petal_color = petal_color
        self.stamen_color = stamen_color
        self.stem_color = stem_color

        self.hideturtle()
        self.speed(0)
        self.penup()
    # draw one petal
    def _draw_one_petal(self, shape : int = 60):
        self.begin_fill()
        self.color(self.petal_color)
        self.pensize(20)
        for _ in range(2):
            self.circle(self.size, shape)
            self.left(120)
        self.end_fill()

    # draw all petals
    def _draw_all_petals(self, shape : int = 60):
        for _ in range(self.petals):
            self.forward(self.size)
            self.pendown()
            self._draw_one_petal(shape)
            self.penup()
            self.goto(self.x, self.y)
            self.left(360/self.petals)

    # draw the stamen
    def _draw_stamen(self, ):
        self.color(self.stamen_color)
        self.goto(self.x, self.y-self.size // 5)
        self.dot(self.size)

    # draw my stem
    def _draw_stem(self):
        self.penup()
        self.goto(self.x, self.y - self.size)
        self.color(self.stem_color)
        self.setheading(270)
        self.pensize(max(1, 15-self.petals))
        self.pendown()
        self.forward(150)
        self.penup()
        print("flower completed")

    # draw one flower
    def draw_one_flower(self, shape : int = 60):
        self.goto(self.x, self.y)
        self.heading()
        self._draw_all_petals(shape)
        self._draw_stamen()
        self._draw_stem()

    # draw buds

for i in range(20):
    f = Flower(
        random.randint(-300, 300),  # random x-coordinate
        random.randint(-300, 300),  # random y-coordinate
        random.randint(6, 12),  # random number of petals
        random.randint(5, 40),  # random flower size
        random.choice(hot_palette),  # random petal color
        random.choice(hot_palette),  # random stamen color
        random.choice(green_palette)  # random stem color
    )
    f.draw_one_flower(random.randint(30, 180))
# main area
# randomization
mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_3123/4141152450.py in <cell line: 0>()
#       3 import math
#       4
# ----> 5 screen = Screen()
#       6 screen.bgcolor("white")
#       7
#
# /usr/lib/python3.12/turtle.py in Screen()
#    3728     else return the existing one."""
#    3729     if Turtle._screen is None:
# -> 3730         Turtle._screen = _Screen()
#    3731     return Turtle._screen
#    3732
#
# /usr/lib/python3.12/turtle.py in __init__(self)
#    3739     def __init__(self):
#    3740         if _Screen._root is None:
# -> 3741             _Screen._root = self._root = _Root()
#    3742             self._root.title(_Screen._title)
#    3743             self._root.ondestroy(self._destroy)
#
# /usr/lib/python3.12/turtle.py in __init__(self)
#     428     """Root class for Screen based on Tkinter."""
#     429     def __init__(self):
# --> 430         TK.Tk.__init__(self)
#     431
#     432     def setupcanvas(self, width, height, cwidth, cheight):
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable
