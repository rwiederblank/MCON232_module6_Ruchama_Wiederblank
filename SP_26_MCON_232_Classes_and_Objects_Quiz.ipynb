# %% [markdown]
# <a href="https://colab.research.google.com/github/rwiederblank/MCON232_module6_Ruchama_Wiederblank/blob/main/SP_26_MCON_232_Classes_and_Objects_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FC Classes and Objects Quiz
# **Module: Classes and Objects in Python**
#
# ## Instructions
# - This quiz is **untimed**.
# - For a **fast student**, this quiz is designed to take about **60 minutes**.
# - If you need to stop in order to **study**, that is allowed. However, please wait **3 hours** before resuming the quiz.
# - If you need a break for any reason **other than study**, you may resume the quiz **immediately** after your break.
# - **Use of AI is forbidden.**
# - Please complete your own work and show what you know.
#
# ## Short reminders before you begin
# A **class** is a blueprint.
# An **object** is one instance created from that blueprint.
# The `__init__` method builds the starting state of each object.
# An **instance attribute** belongs to one object, usually written with `self.attribute_name`.
# A **class attribute** belongs to the class itself and is shared unless shadowed by an instance.
# A **method** is a function inside a class.
# When an object is passed into a method, the method receives a reference to that object.
# If the method **mutates the object's attributes**, the caller sees those changes after the method ends.
# If the method **reassigns the parameter variable** to a different object, that reassignment only changes the local variable inside the method.
#
# ## Academic Integrity
# By submitting this notebook, you are affirming that this work is your own and that you did not use AI or outside help that is not permitted.
#
# ## Requirements
# - for any print statement `__str__` is required
# - all parameters must have a data type associated with it, as well as return type from method.
# - please comment ALL logic (otherwise comments are not necessary)

# %% [markdown]
# ## Quick Reference
# Keep these ideas in mind while working:
#
# - Define a class with `class ClassName:`
# - Build objects with `obj = ClassName(...)`
# - Instance methods usually begin with `self`
# - Access instance data with `self.attribute`
# - Access class data with `ClassName.attribute`
# - You can also read a class attribute through an object, but be careful: assigning through the object can create an instance attribute that shadows the class attribute
# - Passing an object into another object's method allows one object to use the other object's data
# - Mutation persists after the method call
# - Reassignment of the parameter name does not replace the original caller's object

# %%
# Run this cell first.
# You may use it for quick checks throughout the quiz.

def assert_equal(actual, expected, label=""):
    if actual == expected:
        print(f"PASS: {label}")
    else:
        print(f"FAIL: {label}\n  expected: {expected}\n  got:      {actual}")

# %% [markdown]
# # Part A — Concepts and Vocabulary
#
# Answer in full sentences. Keep each answer to about **2–4 sentences**.

# %% [markdown]
# ### Question A1
# What is the difference between a **class** and an **object**?
#
# **Your answer:** A class is kind of like a blueprint with instructions and method for each object. An object is 1 specific instance of the class, with its specific attributes. For example, there may be a dog class, and each specific object would be its own dog with its color, name, and breed.

# %% [markdown]
# ### Question A2
# What is the role of the `__init__` method?
#
# **Your answer:**
# The __init__ method iis where you set up all the starting attributes of the class. For example, if it was a students it may assign the name, grades and subject of the student.

# %% [markdown]
# ### Question A3
# What is the difference between an **instance attribute** and a **class attribute**?
#
# **Your answer:** An instance attribute is different and specfic to each instance of the object. A class attribute is the same for every instance of the class/

# %% [markdown]
# ### Question A4
# When an object is passed to another object's method, what is actually being passed?
#
# **Your answer:** When you pass an object into another objects method, what is actually being passed is a refrence to that object in memory.

# %% [markdown]
# ### Question A5
# What is the difference between **mutating an object** and **reassigning a parameter variable** inside a method?
#
# **Your answer:** Mutating an object is actually changing it, and the user would see that change reflected when it prints. However, reassigning it only changes it within the specific method, and it won't actually be changed in the whole code.

# %% [markdown]
# # Part B — Reading Code
#
# For each question:
# 1. Read the code carefully.
# 2. Predict the output or final object state.
# 3. Then run the code cell if you want to check your thinking.

# %% [markdown]
# ### Question B1 — Basic object state
#
# Before running the code, answer:
# - What are the values of `name` and `score` in `player1` after the object is created?

# %%
class Player:
    def __init__(self, name, score):
        self.name = name
        self.score = score

player1 = Player("Avi", 10)

print(player1.name)
print(player1.score)
# Out:
# Avi
# 10

# %% [markdown]
# **Your answer:** It will print the name "Avi" and then the score, 10.

# %% [markdown]
# ### Question B2 — Class variable vs instance variable
#
# Before running the code, answer:
# - What is printed?
# - Why?

# %%
class Counter:
    total_created = 0

    def __init__(self):
        Counter.total_created += 1

a = Counter()
b = Counter()
c = Counter()

print(Counter.total_created)
# Out:
# 3

# %% [markdown]
# **Your answer:** It will print 3.

# %% [markdown]
# ### Question B3 — Passing one object into another object's method
#
# Before running the code, answer:
# - What is printed?
# - Which object's data is being used?

# %%
class Student:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade

class Reporter:
    def show_student(self, student_obj):
        print(student_obj.name, student_obj.grade)

s1 = Student("Leah", 95)
r = Reporter()
r.show_student(s1)
# Out:
# Leah 95

# %% [markdown]
# **Your answer:**
# It will print: Leah, 95
# The sata being used is from the Student class, whihc is then called by the Reporter class.

# %% [markdown]
# ### Question B4 — Mutation inside a method
#
# Before running the code, answer:
# - What is printed at the end?
# - Why does that change remain after the method call?

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

class BankTeller:
    def deposit_bonus(self, account, amount):
        account.balance += amount

acct = BankAccount("Mina", 100)
teller = BankTeller()
teller.deposit_bonus(acct, 25)

print(acct.balance)
# Out:
# 125

# %% [markdown]
# **Your answer:** It will print 125. It changes because it actually mutated the objects attribute.

# %% [markdown]
# ### Question B5 — Reassigning the parameter inside a method
#
# Before running the code, answer:
# - What is printed?
# - Why does the original object stay the same?

# %%
class Box:
    def __init__(self, value):
        self.value = value

class Changer:
    def replace_box(self, box_obj):
        box_obj = Box(999)
        box_obj.value += 1

b = Box(10)
c = Changer()
c.replace_box(b)

print(b.value)
# Out:
# 10

# %% [markdown]
# **Your answer:** It prints 10 because it only changes within that method, not in the whole code.

# %% [markdown]
# # Part C — Write the Code
#
# Write each class or method in the code cells below.

# %% [markdown]
# ### Question C1 — Create a simple class
#
# Create a class named `Book`.
#
# #### Requirements
# - The constructor should accept:
#   - `title`
#   - `author`
#   - `pages`
# - Store each value in an instance attribute.
# - Then create an object named `b1` with your own sample data.
# - Print the title and author on one line.
# - use `__str__`
#
# **Reminder:** Each object should store its own instance data.

# %%
class Book:
  def __init__(self, title: str, author: str, pages : int):
    self.title = title
    self.author = author
    self.pages = pages

  def __str__(self):
    return f"{self.title} by: {self.author}, {self.pages} pages"

b1 = Book("Harry Potter", "J K Rowling", 729)
print(b1)
# Out:
# Harry Potter by: J K Rowling, 729 pages

# %% [markdown]
# ### Question C2 — Add an instance method
#
# Create a class named `Dog`.
#
# #### Requirements
# - The constructor should accept:
#   - `name`
#   - `age`
# - Store them as instance attributes.
# - Add a method named `describe()` that returns a string like:
#   - `"Fido is 4 years old."`
# - Create one object and test your method.
#
# **Reminder:** Instance methods use `self` to access that object's data.

# %%
class Dog:
  def __init__(self, name : str, age : int):
    self.name = name
    self.age = age

  def describe(self):
    return f"{self.name} is {self.age} years old."

d1 = Dog("Fido", 4)
print(d1.describe())
# Out:
# Fido is 4 years old.

# %% [markdown]
# ### Question C3 — Class variable practice
#
# Create a class named `Student`.
#
# #### Requirements
# - Add a class attribute named `school_name` and set it to `"Touro"`.
# - The constructor should accept:
#   - `name`
#   - `major`
# - Store them as instance attributes.
# - Create two student objects.
# - Print each student's `name`.
# - Print the shared class variable.
#
# **Reminder:** The class variable belongs to the class and is shared.

# %%
class Student:
  school_name = "Touro"

  def __init__(self, name, major):
    self.name = name
    self.major = major

s1 = Student("Sara", "Accounting")
s2 = Student("Rivka", "Nursing")
print(s1.name)
print(s2.name)
print(s1.school_name)
print(s2.school_name)
# Out:
# Sara
# Rivka
# Touro
# Touro

# %% [markdown]
# ### Question C4 — One object uses another object
#
# Create two classes: `Player` and `Coach`.
#
# #### `Player`
# - constructor should accept:
#   - `name`
#   - `points`
#
# #### `Coach`
# - add a method `praise_player(player_obj)` that returns a string like:
#   - `"Great job, Maya! You scored 18 points."`
#
# Create a player object and a coach object, then call the method.
#
# **Reminder:** This question practices passing an object into another object's method and using its data.

# %%
class Player:
  def __init__(self, name : str, points : int):
    self.name = name
    self.points = points

class Coach:
  def praise_player(self, player_obj):
    return f"Great job, {player_obj.name}! You scored {player_obj.points} points."

p1 = Player("Maya", 18)
c1 = Coach()
c1.praise_player(p1)
# Out:
# 'Great job, Maya! You scored 18 points.'

# %% [markdown]
# ### Question C5 — Mutation vs reassignment
#
# Create two classes: `Pet` and `Groomer`.
#
# #### `Pet`
# - constructor should accept:
#   - `name`
#   - `clean`
#
# #### `Groomer`
# Add two methods:
#
# 1. `wash_pet(pet_obj)`
#    - set `pet_obj.clean` to `True`
#
# 2. `replace_pet(pet_obj)`
#    - reassign `pet_obj` to a brand new `Pet("Temporary", True)`
#
# #### After writing the classes
# - Create one pet object that starts dirty.
# - Call `wash_pet(...)`
# - Print the original pet's `name` and `clean` value
# - Then call `replace_pet(...)`
# - Print the original pet's `name` and `clean` value again
#
# #### Finally, answer in a comment:
# - Which method changed the original object?
# - Which method did not?
# - Why?
#
# **Reminder:** Mutation changes the object itself. Reassignment only changes the local parameter name.

# %%
class Pet:
  def __init__(self, name : str, clean : bool):
    self.name = name
    self.clean = clean

  def __str__(self):
    if self.clean == True:
      return f"{self.name} is clean"
    return f"{self.name} is dirty"

class Groomer:
  def wash_pet(self, pet_obj):
    pet_obj.clean = True

  def replace_pet(self, pet_obj):
    pet_obj = Pet("Temporary", True)

p1 = Pet("Frank", False)
print(p1)
print("After groomer: ")
g1 = Groomer()
g1.wash_pet(p1)
print(p1)
print("After replace_pet: ")
g1.replace_pet(p1)
print(p1)

"""
wash_pet changed the object because it mutated it. replace_pet did not chagne the object because it only changed it within the method, not in the whole code.
# Out:
# Frank is dirty
# After groomer:
# Frank is clean
# After replace_pet:
# Frank is clean

# %% [markdown]
# # Part D — Wrap-Up Reflection
#
# Answer in full sentences.
#
# ### Question D1
# What is one thing you understand better now about classes and objects?
# I undertand more, how they can work together with other classes, which kind of reassignments will work and whoc kinds won't.
#
# ### Question D2
# What is still a little confusing or something you would like to practice more?
# I would still like more practise on how to have a counter variable that counts all the instances of a class.

# %% [markdown]
# This quiz took around 35 minutes. I feel like I understand classes well since we had a lot of homework and assignments about them.

# %% [markdown]
# ## Not graded :
# - How do you feel about this topic ?
# - How long did this quiz take you (excluding breaks)
#
# # Thank you !
